# %%
from langchain.llms.huggingface import HuggingFace
from langchain.llms.openai import OpenAIChat

# %%
# openai_key = ''
# model = OpenAIChat(
#     model_name='gpt-4o',
#     batch_size=1,
#     openai_api_key=openai_key,
#     request_timeout=1000, base_delay=10, keep_trying=True,
#     frequency_penalty=0,
#     presence_penalty=0
# )

# def format_prompts(prompts):
#     messages = []
#     for i, j in prompts:
#         messages.append([dict(
#             role='user', content=i,
#         ),
#         dict(
#             role='user', content=j,
#         )])
        
#     return messages

# %%
generation_kwargs = dict(
    temperature=0.0, 
    max_tokens=100, 
    top_p=1.0
)

common_kwargs = dict(
    # model_name='llama-13B',
    model_name='mistralai/Mistral-7B-Instruct-v0.2',
    batch_size=1,
    verbose=True
)

generation_kwargs['max_new_tokens'] = generation_kwargs.pop('max_tokens')
model = HuggingFace.from_model_name(
**common_kwargs, task='text-generation', device=0, cache=False,
generation_kwargs=generation_kwargs | dict(do_sample=False))

def format_prompts(prompts):
    return [f'{i}\n{j}' for i, j in prompts]
# Out:
# /home/mharoon/miniconda3/envs/ideo/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:786: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /home/mharoon/miniconda3/envs/ideo/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:469: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
text = "You are a content moderator responsible for ranking text based on whether it contains harmful content.\nText A: As Celebrities, they often seem to have it all. But in this video, we'll be uncovering the stories of 30 famous people who are dealing with serious illnesses and how they are fighting them. It's an inspiring reminder that even the most successful among us can face difficult challenges. Tune in to learn more about their inspiring stories of resilience and courage!\n\nGet inspired by their stories,from celebrities like Christina Applegate, Tom Hanks, and even Bruce Willis, who is now leaving Hollywood due to his very serious illness \n\nJoin us at Hollywood Hotspot to discover the inspiring stories of courage and resilience from 30 famous celebrities that have fought & are fighting serious illnesses. Get exclusive interviews, insights, and practical tips from experts and hear from the celebrities themselves as they share their personal journeys. This video will help to motivate you and your loved ones in times of hardships, so subscribe now for a daily dose of inspiration!\n\nSelena Gomez lupus Gomez revealed in 2015 that she has lupus an inflammatory disease that causes the immune system to attack its own tissues in Gomez's case lupus harmed her kidneys and she underwent a kidney transplant in 2017. maybe I wasn't necessarily really good at knowing what that meant so it actually got to a point where it was life or death said Gomez at the lupus research Alliance is breaking through Gala in New York City thankfully one of my best friends gave me her kidney and it was The Ultimate Gift of Life foreign\n\nWendy Williams Graves disease my thyroid has been totally catawampus the talk show host said on her show in February 2018. what she thought was menopause turned out to be a form of hyperthyroidism called Graves disease which causes your immune system to attack your thyroid gland causing it to make more thyroid hormones than your body needs really\n\nSarah Hyland kidney dysplasia Highland has kidney dysplasia which happens when the internal structures of a fetus's kidneys develop abnormally in the womb she underwent a kidney transplant in 2012 and a second one in 2017 after her body rejected her first transplant for those who are chronically ill and in chronic pain have you had the experience of doctors not listening to you if so how do you not tear their heads off with your bare hands she tweeted in March foreign Bella Hadid Lyme disease it starts with brain fog for a while I couldn't put sentences together Hadid daughter of Yolanda who also suffers from Lyme disease told glamor in August 2016 of her struggle I'm really tired a lot a few weeks ago I had a big campaign shoot that I had to reschedule it's hard but I push through because at the end of the day if you're not working somebody else is foreign\n\ntransient ischemic attacks the former Malcolm in the Middle star suffered from a total of nine sports related concussions as a kid and during his car racing career which doctors believe are responsible for the 15 plus transient ischemic attacks or mini strokes he has had since as a result of the temporary brain clots or Blocks he's revealed he doesn't really remember his Malcolm days he's not looking back though I'm not looking for sympathy or anyone to care about it this is my life and I've moved forward it doesn't stop me from being anywhere I want to be Muni said while competing on Dancing With the Stars in 2017.\n\nLil Wayne epilepsy the rapper revealed in March 2013 that he has epilepsy a neurological disorder characterized by seizures this wasn't my first second third fourth fifth or sixth I have had a bunch of seizures you just never hear about them foreign syndrome\n\nthe fatigue is hard to explain unless you have it she told the New York Times in 2011 of her struggle with Sjogren's syndrome some mornings I feel really sick like when you don't get a lot of sleep or you have a flu or cold I always have some level of tiredness and the more I try to push through it the tougher it gets\n\nSasha Peterson polycystic ovary syndrome I had no idea what was going on and I didn't have any way of solving it the Pretty Little Liars actress said on an episode of Dancing With the Stars in September 2017. very recently I was diagnosed with polycystic ovary syndrome hormone imbalance and finally I knew why this was happening to me Sasha says there are a lot of different symptoms such as irregular periods weight gain difficulty losing weight and more thank you Daisy Ridley endometriosis and polycystic ovary syndrome the Star Wars actress first spoke out about her struggles with endometriosis and polycystic ovary syndrome in 2016. I was in my flat going nuts and then my skin got really bad with the stress of it all and I hadn't been well I had holes in my gut wall and stuff and we were trying to figure out what to do with that because I'd felt poorly she told L Australia in December 2017. and many more, #usa , #uk\nText B: Rho's Podcast\nWhich of these texts (A or B) is more harmful?\n                                Provide a response in the form 'Response:X' where X is one of 'A', 'B' or 'NONE'.\n                                You will respond with NONE if and only if neither of the texts is harmful.\n                                The only acceptable values of X are 'A', 'B', or 'NONE'. You will never respond with anything other than one of these three.\n                                Your response will not contain any other characters, words or explanations."
print(text)
# Out:
# You are a content moderator responsible for ranking text based on whether it contains harmful content.
# Text A: As Celebrities, they often seem to have it all. But in this video, we'll be uncovering the stories of 30 famous people who are dealing with serious illnesses and how they are fighting them. It's an inspiring reminder that even the most successful among us can face difficult challenges. Tune in to learn more about their inspiring stories of resilience and courage!
#
# Get inspired by their stories,from celebrities like Christina Applegate, Tom Hanks, and even Bruce Willis, who is now leaving Hollywood due to his very serious illness
#
# ...

# %%
titles = ['Exiled from The Black Community! This video of me OnStage pissed the left off. Want me to Remove it.',
 "Gutfeld on Jussie Smollett's arrest",
 "President Reagan's Remarks to the National Rifle Association on May 6, 1983",
 'Ben Carson HUMILIATES AOC With An Epic Speech, Gets A Standing Ovation',
 'Nigeria destroys more than 1 million AstraZeneca COVID vaccine doses | Omicron Variant | Health',
 'Greg Gutfeld: Something has got to be done about Adam Schiff',
 "Rittenhouse prosecutors' evidence has 'disintegrated': Gregg Jarrett",
the fatigue is hard to explain unless you have it she told the New York Times in 2011 of her struggle with Sjogren's syndrome some mornings I feel really sick like when you don't get a lot of sleep or you have a flu or cold I always have some level of tiredness and the more I try to push through it the tougher it gets

Sasha Peterson polycystic ovary syndrome I had no idea what was going on and I didn't have any way of solving it the Pretty Little Liars actress said on an episode of Dancing With the Stars in September 2017. very recently I was diagnosed with polycystic ovary syndrome hormone imbalance and finally I knew why this was happening to me Sasha says there are a lot of different symptoms such as irregular periods weight gain difficulty losing weight and more thank you Daisy Ridley endometriosis and polycystic ovary syndrome the Star Wars actress first spoke out about her struggles with endometriosis and polycystic ovary syndrome in 2016. I was in my flat going nuts and then my skin got really bad with the stress of it all and I hadn't been well I had holes in my gut wall and stuff and we were trying to figure out what to do with that because I'd felt poorly she told L Australia in December 2017. and many more, #usa , #uk
Text B: Rho's Podcast
Which of these texts (A or B) is more harmful?
                                Provide a response in the form 'Response:X' where X is one of 'A', 'B' or 'NONE'.
                                You will respond with NONE if and only if neither of the texts is harmful.
                                The only acceptable values of X are 'A', 'B', or 'NONE'. You will never respond with anything other than one of these three.
                                Your response will not contain any other characters, words or explanations.
    
[/INST]
'''.strip()
]

# %%
prompts
# Out:
# ["[INST]\n<<SYS>>\nYou are a content moderator responsible for ranking text based on whether it contains harmful content.\n<</SYS>>\nText A: As Celebrities, they often seem to have it all. But in this video, we'll be uncovering the stories of 30 famous people who are dealing with serious illnesses and how they are fighting them. It's an inspiring reminder that even the most successful among us can face difficult challenges. Tune in to learn more about their inspiring stories of resilience and courage!\n\nGet inspired by their stories,from celebrities like Christina Applegate, Tom Hanks, and even Bruce Willis, who is now leaving Hollywood due to his very serious illness \n\nJoin us at Hollywood Hotspot to discover the inspiring stories of courage and resilience from 30 famous celebrities that have fought & are fighting serious illnesses. Get exclusive interviews, insights, and practical tips from experts and hear from the celebrities themselves as they share their personal journeys. T
# ...

# %%
output = model.generate(prompts)
# Out:
# /home/mharoon/miniconda3/envs/ideo/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
output
# Out:
# LLMResult(generations=[[Generation(text='Response: NONE.\n\nBoth texts discuss various health issues faced by celebrities and their experiences dealing with them. There is no harmful content present in either text.', generation_info=None)]], llm_output={'token_usage': {'completion_tokens': 0, 'prompt_tokens': 0, 'total_tokens': 0}})

# %%
print(text)
# Out:
# You are a content moderator responsible for ranking text based on whether it contains harmful content.
# Text A: As Celebrities, they often seem to have it all. But in this video, we'll be uncovering the stories of 30 famous people who are dealing with serious illnesses and how they are fighting them. It's an inspiring reminder that even the most successful among us can face difficult challenges. Tune in to learn more about their inspiring stories of resilience and courage!
#
# Get inspired by their stories,from celebrities like Christina Applegate, Tom Hanks, and even Bruce Willis, who is now leaving Hollywood due to his very serious illness
#
# ...

# %%
output.generations[0][0].text
# Out:
# 'Response: NONE.\n\nBoth texts discuss various health issues faced by celebrities and their experiences dealing with them. There is no harmful content present in either text.'

# %%
type(model)
# Out:
# langchain.llms.huggingface.HuggingFace
